# %% [markdown]
# ### P.S -> To predict whether the passenger is survived or not

# %% [markdown]
# ### 1. Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### 2.Load the Dataset

# %%
df=pd.read_csv("C:/Users/Dell/Documents/python assignments/assignments question/titanic-training-data.csv")

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1        S       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5        0       3
# ..           ...      ...     ...
# 886          887        0       2
# 887          888        1       1
# 888          889        0       3
# 889          890        1       1
# 890          891        0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 3.Analyze the dataset like shape,datatypes,missing values,describe etc..

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived        object
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"].fillna(value=df["Age"].mean(),inplace=True)

# %%
df["Cabin"].fillna(value=df["Cabin"].mode(), inplace=True)

# %%
df["Embarked"].fillna(value=df["Embarked"].mode(), inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          685
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   13.002015    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### 4.Show the distribution of survived and not survived

# %%
#type1
sns.countplot(x="Survived",data =df, palette="Set1")
plt.show()

# %%
#type 2
sns.displot(x="Survived",data=df)
plt.show()

# %%
#type 3
df.Survived.value_counts()
# Out:
# 0    548
# 1    342
# S      1
# Name: Survived, dtype: int64

# %% [markdown]
#  ### 5.Show the distribution across pclass

# %%
#type 1
sns.countplot(x="Pclass",data=df, order=df["Pclass"].value_counts(ascending=True).index)
plt.show()

# %%
#type 2
sns.displot(x="Pclass",data=df)
plt.show()

# %%
#type 3
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
#  ### 6. Show the distribution of Embarked

# %%
#type 1
sns.countplot(x="Embarked",data=df)
plt.show()

# %%
#type 2
sns.displot(x="Embarked",data=df)
plt.show()

# %%
#type 3
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### 7. Show the distribution of Age

# %%
#type 1
sns.countplot(x="Age",data=df)
plt.show()

# %%
#type 2
sns.displot(x="Age",data=df)
plt.show()

# %%
#type 3
df.Age.value_counts()
# Out:
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: Age, Length: 89, dtype: int64

# %% [markdown]
# ### 8. Check whether there are outliers in Age

# %%
sns.boxplot(x="Age", data =df,palette="Set1")
plt.show()

# %% [markdown]
# ### 9.Relationship between Pclass and Age

# %%
#type 1
sns.relplot(x="Pclass",y="Age",data=df)
plt.show()

# %%
#type 2
sns.scatterplot(x="Age",y="Pclass", data=df)
plt.show()

# %%
#type 3
relation_of_age_pclass=df[["Age","Pclass"]]

# %%
relation_of_age_pclass.corr()
# Out:
#              Age    Pclass
# Age     1.000000 -0.331339
# Pclass -0.331339  1.000000

# %%
sns.heatmap(relation_of_age_pclass.corr())
# Out:
# <Axes: >

# %% [markdown]
# ### 10.Pairplot for all the numerical attributes

# %%
sns.pairplot(df)
