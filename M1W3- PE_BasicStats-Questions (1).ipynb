# %% [markdown]
# # 1.Import necessary packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.Load the file

# %%
df=pd.read_csv("C:/Users/Dell/Documents/python assignments/eduonix statistics 3 assignment/Inc_Exp_Data.csv")

# %% [markdown]
# # 3.Analyze the data

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %%
print(df.shape)
# Out:
# (50, 7)

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %% [markdown]
# # 4.What is the Mean Expense of a Household?

# %%
df["Mthly_HH_Expense"].mean()
# Out:
# 18818.0

# %% [markdown]
# # 5.What is the Median Household Expense?

# %%
df["Mthly_HH_Expense"].median()
# Out:
# 15500.0

# %% [markdown]
# # 6.What is the Monthly Expense for most of the Households?

# %%
df["Mthly_HH_Expense"].mode()
# Out:
# 0    25000
# Name: Mthly_HH_Expense, dtype: int64

# %% [markdown]
# # 7.Plot the Histogram to count the Highest qualified member

# %%
plt.hist(x="Highest_Qualified_Member",data=df)
plt.show() # to show the output

# %%
#in the above cell we can see that there are most number of graduate's are present in Highest_Qualified_Member

# %% [markdown]
# # 8.Calculate IQR(difference between 75% and 25% quartile)

# %%
df.describe()
# Out:
#        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count        50.000000         50.000000          50.000000        50.000000
# mean      41558.000000      18818.000000           4.060000      3060.000000
# std       26097.908979      12090.216824           1.517382      6241.434948
# min        5000.000000       2000.000000           1.000000         0.000000
# 25%       23550.000000      10000.000000           3.000000         0.000000
# 50%       35000.000000      15500.000000           4.000000         0.000000
# 75%       50375.000000      25000.000000           5.000000      3500.000000
# max      100000.000000      50000.000000           7.000000     35000.000000
#
#        Annual_HH_Income  No_of_Earning_Members
# count      5.000000e+01              50.000000
# mean       4.900190e+05               1.460000
# std        3.201358e+05               0.734291
# min        6.420000e+04               1.000000
# ...

# %% [markdown]
# # 9.Calculate Standard Deviation for first 4 columns.

# %%
df[df.columns[:4]].std()
# Out:
# Mthly_HH_Income      26097.908979
# Mthly_HH_Expense     12090.216824
# No_of_Fly_Members        1.517382
# Emi_or_Rent_Amt       6241.434948
# dtype: float64

# %% [markdown]
# # 10.Calculate Variance for first 3 columns.

# %%
df[df.columns[:4]].var()
# Out:
# Mthly_HH_Income      6.811009e+08
# Mthly_HH_Expense     1.461733e+08
# No_of_Fly_Members    2.302449e+00
# Emi_or_Rent_Amt      3.895551e+07
# dtype: float64

# %% [markdown]
# # 11.Calculate the count of Highest qualified member.

# %%
df["Highest_Qualified_Member"].mode()
# Out:
# 0    Graduate
# Name: Highest_Qualified_Member, dtype: object

# %%
df["Highest_Qualified_Member"].value_counts()
# Out:
# Graduate          19
# Under-Graduate    10
# Professional      10
# Post-Graduate      6
# Illiterate         5
# Name: Highest_Qualified_Member, dtype: int64

# %%
# we can see in the above two cells that graduate is highest and it has occured 19 times

# %%
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %% [markdown]
# # 12.Plot the Histogram to count the No_of_Earning_Members

# %%
sns.countplot(x="No_of_Earning_Members",data =df)
# Out:
# <Axes: xlabel='No_of_Earning_Members', ylabel='count'>

# %% [markdown]
# # 13.Suppose you have option to invest in Stock A or Stock B. The stocks • have different expected returns and standard deviations. The expected return of Stock A is 15% and Stock B is 10%. Standard Deviation of the returns of these stocks is 10% and 5% respectively.
#
# Which is better investment?

# %%
""" I will invest in stock B because stock B is more stable than stock A , As it has less standard deviation.
    Here actual return is  5% on the both stock by the formula-
    Actual Return=Expected Return-Standard Deviation
    So for Stock A--->15%-10%=5%
    And for Stock B--->15%-10%=5%
    Here B stock is Stable & A is volatile So A is a risky asset, So I will prefer B
   """
# Out:
# ' I will invest in stock B because stock B is more stable than stock A , As it has less standard deviation.\n    Here actual return is  5% on the both stock by the formula-\n    Actual Return=Expected Return-Standard Deviation\n    So for Stock A--->15%-10%=5%\n    And for Stock B--->15%-10%=5%\n    Here B stock is Stable & A is volatile So A is a risky asset, So I will prefer B\n   '
