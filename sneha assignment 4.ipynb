# %% [markdown]
# # Exercise - Visualization of Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from the AutoMPG dataset file. Assign it to a variable called mpg_df

# %%
df=pd.read_csv("https://raw.githubusercontent.com/joanby/python-ml-course/master/datasets/auto/auto-mpg.csv")

# %% [markdown]
# ### Step 3. Perform basic EDA to understand the structure of the data

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 401  27.0          4         140.0        86.0    2790          15.6
# 402  44.0          4          97.0        52.0    2130          24.6
# 403  32.0          4         135.0        84.0    2295          11.6
# 404  28.0          4         120.0        79.0    2625          18.6
# 405  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 401          82       1            ford mustang gl
# 402          82       2                  vw pickup
# 403          82       1              dodge rampage
# 404          82       1                ford ranger
# 405          82       1                 chevy s-10
#
# [406 rows x 9 columns]

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  406.000000    406.000000  400.000000   406.000000
# mean    23.514573    5.475369    194.779557  105.082500  2979.413793
# std      7.815984    1.712160    104.922458   38.768779   847.004328
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    105.000000   75.750000  2226.500000
# 50%     23.000000    4.000000    151.000000   95.000000  2822.500000
# 75%     29.000000    8.000000    302.000000  130.000000  3618.250000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    406.000000  406.000000  406.000000
# mean      15.519704   75.921182    1.568966
# std        2.803359    3.748737    0.797479
# min        8.000000   70.000000    1.000000
# 25%       13.700000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
df.dtypes # checking the data types
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     406 non-null    int64
#  2   displacement  406 non-null    float64
#  3   horsepower    400 non-null    float64
#  4   weight        406 non-null    int64
#  5   acceleration  406 non-null    float64
#  6   model year    406 non-null    int64
#  7   origin        406 non-null    int64
#  8   car name      406 non-null    object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.7+ KB

# %% [markdown]
# ### Step 4. Check and handle the missing values, if any.

# %%
df.isnull().sum()
# Out:
# mpg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df["mpg"]=df["mpg"].fillna(df["mpg"].mean()) # replacing the null values with the mean

# %%
df["horsepower"]=df["horsepower"].fillna(df["horsepower"].mean())

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# ### Step 5. Create a plot to check the relationship between horsepower and acceleration. Note down your insight for the same. Beautify the graph using various customizations.

# %%
sns.relplot(x="horsepower",y="acceleration",data=df,color="blue",marker="o")
plt.title("relationship between horsepower and acceleration",loc="Right",color="red")
plt.xlabel("horsepower",color="orange")
plt.ylabel("acceleration",color="green")
plt.show()

# %% [markdown]
# ### Step 6. Generate subplots to display the histograms for acceleration, displacement and weight and kilometer_per_litre. Note down your insight for the same

# %%
plt.subplot(2,1,1)
plt.scatter(df["acceleration"],df["displacement"])
plt.title("histoigram of acceleration & displacement")
plt.xlabel("acceleration")
plt.ylabel("displacement")
plt.show()

plt.subplot(2,1,2)
plt.scatter(df["weight"],df["mpg"])
plt.title("histoigram of weight & mpg")
plt.xlabel("weight")
plt.ylabel("mpg")
plt.show()

# %% [markdown]
# ### Step 7. Create a plot to check the relationship between displacement and weight for origin 2, color the datapoints based on no of cylinders. Note down your insight for the same and save the plot as an image file.

# %%
origin_df=df[df["origin"]==2] # here i am making a new data set in which i am changing the data set in which origin is 2
origin_df
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 10   23.514573          4         133.0       115.0    3090          17.5
# 25   26.000000          4          97.0        46.0    1835          20.5
# 26   25.000000          4         110.0        87.0    2672          17.5
# 27   24.000000          4         107.0        90.0    2430          14.5
# 28   25.000000          4         104.0        95.0    2375          17.5
# ..         ...        ...           ...         ...     ...           ...
# 366  28.100000          4         141.0        80.0    3230          20.4
# 367  23.514573          4         121.0       110.0    2800          15.4
# 368  30.700000          6         145.0        76.0    3160          19.6
# 383  36.000000          4         105.0        74.0    1980          15.3
# 402  44.000000          4          97.0        52.0    2130          24.6
#
#      model year  origin                      car name
# 10           70       2          citroen ds-21 pallas
# 25           70       2  volkswagen 1131 deluxe sedan
# 26           70       2                   peugeot 504
# 27           70       2                   audi 100 ls
# 28           70       2                      saab 99e
# ..          ...     ...                           ...
# 366          81       2     peugeot 505s turbo diesel
# 367          81       2                     saab 900s
# 368          81       2                  volvo diesel
# 383          82       2           volkswagen rabbit l
# 402          82       2                     vw pickup
#
# [73 rows x 9 columns]

# %%
sns.relplot(x=df["displacement"],y=df["weight"],hue="cylinders",data=origin_df,palette='Set2')
xlabel=("displacement")
ylabel=("weight")
plt.show()

# %% [markdown]
# ### Step 8. Display the frequency distribution of the Origin variable. Note down your insight for the same

# %%
plt.hist(df["origin"])
plt.show()

# %% [markdown]
# ### Step 9. Check the relationship of multiple variables wrt kilometer_per_litre. Note down your insight for the same

# %%
sns.pairplot(hue="mpg",data=df)
plt.show()

# %% [markdown]
# ### Step 10. Display the average weight based on no of cylinders present. Note down the insight for the same

# %%
avg_weight_of_cylinders=df.groupby("cylinders").weight.mean() # using groupby function 
avg_weight_of_cylinders
# Out:
# cylinders
# 3    2398.500000
# 4    2312.685990
# 5    3103.333333
# 6    3198.226190
# 8    4105.194444
# Name: weight, dtype: float64

# %% [markdown]
# ### Step 11. Check for the outliers in the dataset. Note down the insight for the same.

# %%
df.boxplot(figsize=(10,15))
plt.show() # here we can see that every column is having some outliers

# %% [markdown]
# ### Step 12. Plot the correlations for variables.

# %%
df.corr() # using corr() method to display correltion
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_4076\4113239596.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() # using corr() method to display correltion
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.762698     -0.791268   -0.758059 -0.823327
# cylinders    -0.762698   1.000000      0.951787    0.840140  0.895220
# displacement -0.791268   0.951787      1.000000    0.894719  0.932475
# horsepower   -0.758059   0.840140      0.894719    1.000000  0.862617
# weight       -0.823327   0.895220      0.932475    0.862617  1.000000
# acceleration  0.409338  -0.522452     -0.557984   -0.692274 -0.430086
# model year    0.565698  -0.360762     -0.381714   -0.419758 -0.315389
# origin        0.561059  -0.567478     -0.613056   -0.458538 -0.584109
#
#               acceleration  model year    origin
# mpg               0.409338    0.565698  0.561059
# cylinders        -0.522452   -0.360762 -0.567478
# displacement     -0.557984   -0.381714 -0.613056
# horsepower       -0.692274   -0.419758 -0.458538
# weight           -0.430086   -0.315389 -0.584109
# acceleration      1.000000    0.301992  0.218845
# model year        0.301992    1.000000  0.187656
# origin            0.218845    0.187656  1.000000
